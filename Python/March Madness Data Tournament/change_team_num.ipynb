# %% [markdown]
# # Exchange team1 and team2 information to fit for machine learning

# %% [markdown]
# ### Problem Statement: team1 always has higher score than team2 in original data, which results in the outcome column is all "Win" based on "team1_Score >team2_score"
#
# ### Solution: Exchange half of team1 and team2 information

# %%
import pandas as pd
import numpy as np
from copy import deepcopy

df = pd.read_csv('F:\\2019Spring\\march madness\\New folder\\NCAA_Tourney_2002_2018.csv')
df.head()
# Out:
#    team1_id  team1_score  team2_id  team2_score WLoc  num_ot team1_position  \
# 0      1104           86      1194           78    N       0            Y02
# 1      1112           86      1364           81    N       0            Z03
# 2      1181           84      1457           37    N       0            Y01
# 3      1231           75      1428           56    N       0            Y05
# 4      1242           70      1221           59    N       0            X01
#
#   team2_position  team1_seed  team2_seed       ...        team1_adjoe  \
# 0            Y15           2          15       ...           111.4954
# 1            Z14           3          14       ...           117.3877
# 2            Y16           1          16       ...           118.5999
# 3            Y12           5          12       ...           109.6136
# 4            X16           1          16       ...           115.0406
#
#    team1_de team1_adjde team2_tempo team2_adjtempo  team2_oe team2_adjoe  \
# ...

# %%
alist = list(df.columns)
newlist = deepcopy(alist)
alist
# Out:
# ['team1_id',
#  'team1_score',
#  'team2_id',
#  'team2_score',
#  'WLoc',
#  'num_ot',
#  'team1_position',
#  'team2_position',
#  'team1_seed',
#  'team2_seed',
#  'strongseed',
#  'weakseed',
#  'team1_region',
#  'team2_region',
#  'slot',
#  'team1_teamname',
#  'team2_teamname',
#  'season',
#  'host',
#  'host_lat',
#  'host_long',
#  'team1_lat',
#  'team1_long',
#  'team2_lat',
#  'team2_long',
#  'team1_coach_id',
#  'team1_pt_school_ncaa',
#  'team1_pt_overall_ncaa',
#  'team1_pt_school_s16',
#  'team1_pt_overall_s16',
#  'team1_pt_school_ff',
#  'team1_pt_overall_ff',
#  'team1_pt_career_school_wins',
#  'team1_pt_career_school_losses',
#  'team1_pt_career_overall_wins',
#  'team1_pt_career_overall_losses',
#  'team1_pt_team_season_wins',
#  'team1_pt_team_season_losses',
#  'team1_pt_coach_season_wins',
#  'team1_pt_coach_season_losses',
#  'team2_coach_id',
#  'team2_pt_school_ncaa',
#  'team2_pt_overall_ncaa',
#  'team2_pt_school_s16',
#  'team2_pt_overall_s16',
# ...

# %%
for i in range(len(newlist)):
    if newlist[i].startswith('team1'):
        newlist[i] = newlist[i].replace('team1','team2')
    elif newlist[i].startswith('team2'):
        newlist[i] = newlist[i].replace('team2','team1')
    else:
        print(newlist[i])
newlist
# Out:
# WLoc
# num_ot
# strongseed
# weakseed
# slot
# season
# host
# host_lat
# host_long
# game_id
# ['team2_id',
#  'team2_score',
#  'team1_id',
#  'team1_score',
#  'WLoc',
#  'num_ot',
#  'team2_position',
#  'team1_position',
#  'team2_seed',
#  'team1_seed',
#  'strongseed',
#  'weakseed',
#  'team2_region',
#  'team1_region',
#  'slot',
#  'team2_teamname',
#  'team1_teamname',
#  'season',
#  'host',
#  'host_lat',
#  'host_long',
#  'team2_lat',
#  'team2_long',
#  'team1_lat',
#  'team1_long',
#  'team2_coach_id',
#  'team2_pt_school_ncaa',
#  'team2_pt_overall_ncaa',
#  'team2_pt_school_s16',
#  'team2_pt_overall_s16',
#  'team2_pt_school_ff',
#  'team2_pt_overall_ff',
#  'team2_pt_career_school_wins',
#  'team2_pt_career_school_losses',
#  'team2_pt_career_overall_wins',
#  'team2_pt_career_overall_losses',
#  'team2_pt_team_season_wins',
#  'team2_pt_team_season_losses',
#  'team2_pt_coach_season_wins',
#  'team2_pt_coach_season_losses',
#  'team1_coach_id',
# ...

# %%
ncdf = pd.read_csv('F:\\2019Spring\\march madness\\New folder\\NCAA_Tourney_2002_2018.csv',names=newlist)
newdf= ncdf.drop(index = 0)
newdf = newdf.reset_index(drop=True)
newdf.head()
# Out:
#   team2_id team2_score team1_id team1_score WLoc num_ot team2_position  \
# 0     1104          86     1194          78    N      0            Y02
# 1     1112          86     1364          81    N      0            Z03
# 2     1181          84     1457          37    N      0            Y01
# 3     1231          75     1428          56    N      0            Y05
# 4     1242          70     1221          59    N      0            X01
#
#   team1_position team2_seed team1_seed       ...       team2_adjoe  team2_de  \
# 0            Y15          2         15       ...          111.4954   95.2313
# 1            Z14          3         14       ...          117.3877  104.0411
# 2            Y16          1         16       ...          118.5999   90.2544
# 3            Y12          5         12       ...          109.6136   94.4987
# 4            X16          1         16       ...          115.0406   94.4261
#
#   team2_adjde team1_tempo team1_adjtempo  team1_oe team1_adjoe team1_de  \
# ...

# %%
order = alist
betterdf = newdf[alist]

# %%
gameid = betterdf['game_id']
newid = []
for i in gameid:
    idlist = i.split('-')
    t1 = idlist[1]
    t2 = idlist[2]
    idlist[1] = t2
    idlist[2] = t1
    newid.append('-'.join(idlist))

print(len(newid))
# Out:
# 1111

# %%
id = pd.DataFrame(newid,columns=['game_id'])
id
# Out:
#              game_id
# 0     2002-1194-1104
# 1     2002-1364-1112
# 2     2002-1457-1181
# 3     2002-1428-1231
# 4     2002-1221-1242
# 5     2002-1329-1245
# 6     2002-1434-1246
# 7     2002-1274-1281
# 8     2002-1150-1323
# 9     2002-1172-1326
# 10    2002-1285-1332
# 11    2002-1443-1390
# 12    2002-1266-1409
# 13    2002-1425-1423
# 14    2002-1337-1448
# 15    2002-1211-1461
# 16    2002-1335-1143
# 17    2002-1131-1153
# 18    2002-1214-1163
# 19    2002-1196-1166
# 20    2002-1293-1208
# 21    2002-1361-1228
# 22    2002-1373-1268
# 23    2002-1270-1280
# 24    2002-1277-1301
# 25    2002-1227-1328
# 26    2002-1148-1338
# 27    2002-1403-1356
# 28    2002-1130-1400
# 29    2002-1279-1417
# ...              ...
# 1081  2018-1371-1242
# 1082  2018-1348-1181
# 1083  2018-1326-1211
# 1084  2018-1397-1260
# 1085  2018-1222-1276
# 1086  2018-1196-1403
# 1087  2018-1138-1246
# 1088  2018-1139-1345
# 1089  2018-1267-1452
# 1090  2018-1277-1393
# 1091  2018-1120-1155
# ...

# %%
be2df = betterdf.drop(['game_id'],axis=1)
be2df.head()
len(be2df)
# Out:
# 1111

# %%
best =pd.concat([be2df,id],axis=1)
best
# Out:
#      team1_id team1_score team2_id team2_score WLoc num_ot team1_position  \
# 0        1194          78     1104          86    N      0            Y15
# 1        1364          81     1112          86    N      0            Z14
# 2        1457          37     1181          84    N      0            Y16
# 3        1428          56     1231          75    N      0            Y12
# 4        1221          59     1242          70    N      0            X16
# 5        1329          61     1245          69    N      0            Y07
# 6        1434          68     1246          83    N      0            W13
# 7        1274          80     1281          93    N      0            Z05
# 8        1150          63     1323          82    N      0            Y09
# 9        1172          64     1326          69    N      0            Z13
# 10       1285          62     1332          81    N      0            X15
# 11       1443          68     1390          84    N      0            X09
# ...

# %%
wholedf =pd.concat([df,best],axis=0)
wholedf = wholedf.reset_index(drop=True)
wholedf
# Out:
#      team1_id team1_score team2_id team2_score WLoc num_ot team1_position  \
# 0        1104          86     1194          78    N      0            Y02
# 1        1112          86     1364          81    N      0            Z03
# 2        1181          84     1457          37    N      0            Y01
# 3        1231          75     1428          56    N      0            Y05
# 4        1242          70     1221          59    N      0            X01
# 5        1245          69     1329          61    N      0            Y10
# 6        1246          83     1434          68    N      0            W04
# 7        1281          93     1274          80    N      0            Z12
# 8        1323          82     1150          63    N      0            Y08
# 9        1326          69     1172          64    N      0            Z04
# 10       1332          81     1285          62    N      0            X02
# 11       1390          84     1443          68    N      0            X08
# ...

# %%
for i in range(555,1666):
    wholedf= wholedf.drop(index = i)

wholedf
# Out:
#      team1_id team1_score team2_id team2_score WLoc num_ot team1_position  \
# 0        1104          86     1194          78    N      0            Y02
# 1        1112          86     1364          81    N      0            Z03
# 2        1181          84     1457          37    N      0            Y01
# 3        1231          75     1428          56    N      0            Y05
# 4        1242          70     1221          59    N      0            X01
# 5        1245          69     1329          61    N      0            Y10
# 6        1246          83     1434          68    N      0            W04
# 7        1281          93     1274          80    N      0            Z12
# 8        1323          82     1150          63    N      0            Y08
# 9        1326          69     1172          64    N      0            Z04
# 10       1332          81     1285          62    N      0            X02
# 11       1390          84     1443          68    N      0            X08
# ...

# %%
wholedf.to_csv('F:\\2019Spring\\march madness\\New folder\\comeon.csv', index=False)
